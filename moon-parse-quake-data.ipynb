# %%
from xml.etree import cElementTree as ElementTree
from urllib.request import urlopen

# %%
#
# Some generic utilities I use to parse the xml
#
#---------------------------------------------------------------------------------
# function to search an xml item for the value specified by the key
#   returns the value if the item is not found, the string 'None' is returned
#   if the value is not found.
#---------------------------------------------------------------------------------
def get_xitem_as_text(item,key):
    anItem = item.find(key,ns)
    if(anItem != None):
        return anItem.text
    else:
        return 'None'
#
#---------------------------------------------------------------------------------
#  same type of function as above, but this one also checks that the item
#     has a value provided.
#---------------------------------------------------------------------------------
def get_xitem_value_as_text(item,key,valuekey):
    anItem = item.find(key,ns)
    if(anItem == None):
        return 'None'
    else:
        value = anItem.find(valuekey,ns)
        if(value != None):
            return value.text
        else:
            return 'None'
#
#---------------------------------------------------------------------------------
def search_pdicts(key, value, list_of_dictionaries):
    return [element for element in list_of_dictionaries if element[key] == value]
#

# %% [markdown]
# Functions used to parse

# %%
#
# To make outputting information simple, I insure that certain values are in each dictionary,  
#   whether they are defined in the xml or not. These dictionaries set up default values,
#   but as the xml is parsed, defined key value pairs are updated.
#
defaultPick = {'stationCode':'--','networkCode':'--','phase':'NA','time':'NA'}
#
defaultArrival = {'genericAmplitude':'NA','type':'NA','unit':'NA',
                  'period':'NA', 'evaluationMode':'NA','timeResidual':'NA',
                  'timeWeight':'NA'}
#
defaultAmplitude = {'pickID':'NA','genericAmplitude':'NA','period':'NA',
                  'unit':'NA'}  

#---------------------------------------------------------------------------------
# PICKS
def parse_picks(xev):
    xpicks = xev.findall('d:pick',ns)
    picks = []
    for pick in xpicks:
        pdict = defaultPick.copy()
        pdict.update(pick.attrib.copy())
        
        value = get_xitem_value_as_text(pick,'d:time','d:value')
        if(value!='None' or 'NA'):
            pdict.update({"time" :value})

        value = get_xitem_as_text(pick,'d:phaseHint')
        if(value!='None' or 'NA'):
            pdict.update({"phase" :value})
        pdict.update(pick.find('d:waveformID',ns).attrib)
        picks.append(pdict)
    return picks
#
#---------------------------------------------------------------------------------

# AMPLITUDES
def parse_amplitudes(xevent):
    xamplitudes = xevent.findall('d:amplitude',ns)
    amplitudes = []
    for xamp in xamplitudes:
        adict = xamp.attrib.copy()
        adict.update(defaultAmplitude)

        value = xamp.find('d:waveformID',ns)
        if(value != None):
            adict.update(value.attrib)
        
        value = get_xitem_value_as_text(xamp,'d:genericAmplitude','d:value')
        if(value!='None' or 'NA'):
            adict.update({"genericAmplitude" :value})

        value = get_xitem_as_text(xamp,'d:unit')
        if(value!='None' or 'NA'):
            adict.update({"unit" :value})
          
        amplitudes.append(adict)

    return amplitudes

#---------------------------------------------------------------------------------

# TYPE OF EVENT
def parse_types(xev):
    types = []
    xtypes = xev.findall('d:type',ns)  
    for type in xtypes:
        types.append(type.text)   
    return types

#---------------------------------------------------------------------------------

# DESCRIPTION OF EVENT
def parse_descriptions(xev):
    descriptions = []
    xdescriptions = xev.findall('d:description', ns)
    for description in xdescriptions:
        value = get_xitem_as_text(description,'d:text')      
        descriptions.append(value)
        
        
    return descriptions

# %%
# Namespaces
ns = {'q' : 'http://quakeml.org/xmlns/quakeml/1.2',
     'd': 'http://quakeml.org/xmlns/bed/1.2',
     'my_ns' : 'http://test.org/xmlns/0.1',
     'ns0' : 'http://some-page.de/xmlns/0.1',
     'ns1' : 'http://some-page.de/xmlns/1.0'}

def parse_usgs_xml(filepath):
    xtree = ElementTree.parse(filepath)
    xroot = xtree.getroot()
    #
    xeventParameters = xroot.findall('d:eventParameters',ns)
    #
    for ep in xeventParameters:
        xevents = ep.findall('d:event',ns)
        print(f'Found {(len(xevents))} events.' ) 
    #    
    events = []
    #
    i = 0
    for xev in xevents:
        # build an event dictionary 
        ev = {}
        ev['publicID'] = xev.attrib['publicID']
        #
        picks = parse_picks(xev)
        amplitudes = parse_amplitudes(xev)
        types = parse_types(xev)
        descriptions = parse_descriptions(xev)
        #   
        events.append({'eventInfo':ev, 'eventType':types, 'eventDescription': descriptions, 
                       'picks':picks,'amplitudes':amplitudes})
        #
        i += 1
        #
        print (f'parsed {i} events.')
        #
    return events

# %%
# Filepath to parse
events = parse_usgs_xml("LunarCatalog_Nakamura_1981_and_updates_v1.xml")

# %%
events
# Out:
# [{'eventInfo': {'publicID': 'smi:nakamura81/event/00001'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['unclassified deep moonquake'],
#   'picks': [{'stationCode': 'S11',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-07-27T23:48:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S11/00001',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S11/00001',
#     'pickID': 'NA',
#     'genericAmplitude': '3.1',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00002'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S11',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-07-28T11:46:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S11/00002',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S11/00002',
#     'pickID': 'NA',
#     'genericAmplitude': '1.8',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00003'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S11',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-07-28T13:49:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S11/00003',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S11/00003',
#     'pickID': 'NA',
#     'genericAmplitude': '3.7',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00004'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S11',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-07-29T13:18:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S11/00004',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S11/00004',
#     'pickID': 'NA',
#     'genericAmplitude': '1.9',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00005'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S11',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-08-02T17:20:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S11/00005',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S11/00005',
#     'pickID': 'NA',
#     'genericAmplitude': '1.9',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00006'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S11',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-08-21T18:58:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S11/00006',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S11/00006',
#     'pickID': 'NA',
#     'genericAmplitude': '5.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00007'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S11',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-08-23T00:09:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S11/00007',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S11/00007',
#     'pickID': 'NA',
#     'genericAmplitude': '1.6',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00008'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['unclassified deep moonquake'],
#   'picks': [{'stationCode': 'S11',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-08-24T06:18:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S11/00008',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S11/00008',
#     'pickID': 'NA',
#     'genericAmplitude': '5.1',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00009'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S11',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-08-25T00:30:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S11/00009',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S11/00009',
#     'pickID': 'NA',
#     'genericAmplitude': '4.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00010'},
#   'eventType': ['crash'],
#   'eventDescription': ['LM impact'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-11-20T22:17:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00010',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00010',
#     'pickID': 'NA',
#     'genericAmplitude': '30.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00011'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-11-24T07:51:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00011',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00011',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00012'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-11-27T03:18:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00012',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00012',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00013'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-11-28T03:39:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00013',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00013',
#     'pickID': 'NA',
#     'genericAmplitude': '-1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00014'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-11-28T10:02:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00014',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00014',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00015'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-11-29T09:10:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00015',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00015',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00016'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-11-29T11:55:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00016',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00016',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00017'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-11-30T03:24:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00017',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00017',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00018'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-11-30T06:28:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00018',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00018',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00019'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-11-30T11:48:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00019',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00019',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00020'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-11-30T19:15:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00020',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00020',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00021'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-01T01:02:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00021',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00021',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00022'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-01T05:28:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00022',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00022',
#     'pickID': 'NA',
#     'genericAmplitude': '2.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00023'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-01T06:52:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00023',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00023',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00024'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-01T10:52:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00024',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00024',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00025'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-02T00:04:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00025',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00025',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00026'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-02T02:43:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00026',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00026',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00027'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-02T13:55:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00027',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00027',
#     'pickID': 'NA',
#     'genericAmplitude': '2.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00028'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-05T17:29:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00028',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00028',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00029'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-06T20:33:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00029',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00029',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00030'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-08T01:44:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00030',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00030',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00031'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-08T08:13:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00031',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00031',
#     'pickID': 'NA',
#     'genericAmplitude': '0.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00032'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-09T19:03:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00032',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00032',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00033'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-10T14:43:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00033',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00033',
#     'pickID': 'NA',
#     'genericAmplitude': '-1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00034'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-10T21:32:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00034',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00034',
#     'pickID': 'NA',
#     'genericAmplitude': '8.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00035'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-11T02:01:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00035',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00035',
#     'pickID': 'NA',
#     'genericAmplitude': '0.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00036'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-11T04:03:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00036',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00036',
#     'pickID': 'NA',
#     'genericAmplitude': '0.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00037'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-11T10:55:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00037',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00037',
#     'pickID': 'NA',
#     'genericAmplitude': '0.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00038'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-11T19:05:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00038',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00038',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00039'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-12T01:54:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00039',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00039',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00040'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-12T08:20:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00040',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00040',
#     'pickID': 'NA',
#     'genericAmplitude': '-1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00041'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-12T18:46:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00041',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00041',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00042'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-13T03:22:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00042',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00042',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00043'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-13T07:21:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00043',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00043',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00044'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-13T07:40:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00044',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00044',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00045'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-13T14:57:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00045',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00045',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00046'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-13T18:54:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00046',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00046',
#     'pickID': 'NA',
#     'genericAmplitude': '0.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00047'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-13T22:29:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00047',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00047',
#     'pickID': 'NA',
#     'genericAmplitude': '0.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00048'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-14T02:13:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00048',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00048',
#     'pickID': 'NA',
#     'genericAmplitude': '0.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00049'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-14T02:30:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00049',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00049',
#     'pickID': 'NA',
#     'genericAmplitude': '-1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00050'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-14T04:33:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00050',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00050',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00051'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-14T09:03:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00051',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00051',
#     'pickID': 'NA',
#     'genericAmplitude': '3.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00052'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-14T22:18:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00052',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00052',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00053'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-14T23:44:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00053',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00053',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00054'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-15T13:22:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00054',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00054',
#     'pickID': 'NA',
#     'genericAmplitude': '0.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00055'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-16T00:27:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00055',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00055',
#     'pickID': 'NA',
#     'genericAmplitude': '6.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00056'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-18T03:14:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00056',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00056',
#     'pickID': 'NA',
#     'genericAmplitude': '-1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00057'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-21T00:31:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00057',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00057',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00058'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-23T04:12:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00058',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00058',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00059'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-23T22:21:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00059',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00059',
#     'pickID': 'NA',
#     'genericAmplitude': '3.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00060'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-26T19:14:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00060',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00060',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00061'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-26T22:27:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00061',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00061',
#     'pickID': 'NA',
#     'genericAmplitude': '2.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00062'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-27T09:04:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00062',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00062',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00063'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-27T13:40:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00063',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00063',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00064'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-27T21:32:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00064',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00064',
#     'pickID': 'NA',
#     'genericAmplitude': '3.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00065'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-28T02:41:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00065',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00065',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00066'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-28T07:05:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00066',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00066',
#     'pickID': 'NA',
#     'genericAmplitude': '0.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00067'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-28T07:45:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00067',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00067',
#     'pickID': 'NA',
#     'genericAmplitude': '0.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00068'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-28T08:50:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00068',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00068',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00069'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-28T11:27:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00069',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00069',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00070'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-29T02:42:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00070',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00070',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00071'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1969-12-29T22:35:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00071',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00071',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00072'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-01T01:40:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00072',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00072',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00073'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-02T02:20:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00073',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00073',
#     'pickID': 'NA',
#     'genericAmplitude': '6.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00074'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-02T21:18:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00074',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00074',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00075'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-03T09:08:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00075',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00075',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00076'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-03T11:25:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00076',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00076',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00077'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-03T12:42:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00077',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00077',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00078'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-03T16:24:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00078',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00078',
#     'pickID': 'NA',
#     'genericAmplitude': '3.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00079'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-04T11:20:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00079',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00079',
#     'pickID': 'NA',
#     'genericAmplitude': '0.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00080'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-04T11:54:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00080',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00080',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00081'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-04T16:03:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00081',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00081',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00082'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-04T21:05:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00082',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00082',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00083'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-06T03:53:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00083',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00083',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00084'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-06T13:28:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00084',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00084',
#     'pickID': 'NA',
#     'genericAmplitude': '4.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00085'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-06T21:58:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00085',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00085',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00086'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-07T02:04:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00086',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00086',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00087'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-07T09:10:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00087',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00087',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00088'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-07T11:08:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00088',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00088',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00089'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-08T00:49:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00089',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00089',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00090'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-08T04:40:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00090',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00090',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00091'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-08T12:49:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00091',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00091',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00092'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-08T16:40:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00092',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00092',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00093'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-09T01:08:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00093',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00093',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00094'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1970-01-09T02:03:00.000000Z',
# ...
#     'phase': 'P',
#     'time': '1971-03-24T05:12:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00975',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00975',
#     'pickID': 'NA',
#     'genericAmplitude': '3.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00976'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-24T06:29:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00976',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00976',
#     'pickID': 'NA',
#     'genericAmplitude': '1.7',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00977'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-24T06:59:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00977',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00977',
#     'pickID': 'NA',
#     'genericAmplitude': '2.2',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00978'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-24T08:04:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00978',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00978',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00979'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-24T10:22:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00979',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00979',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00980'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-24T11:51:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00980',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00980',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00981'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-24T18:26:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00981',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00981',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00982'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-24T22:50:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00982',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00982',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00983'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-25T05:56:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00983',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00983',
#     'pickID': 'NA',
#     'genericAmplitude': '1.2',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00984'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-25T08:06:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00984',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00984',
#     'pickID': 'NA',
#     'genericAmplitude': '2.2',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00985'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-25T11:09:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00985',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00985',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00986'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-25T15:18:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00986',
#     'channelCode': '',
#     'locationCode': ''},
#    {'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-25T15:18:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00986',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00986',
#     'pickID': 'NA',
#     'genericAmplitude': '5.0',
#     'period': 'NA',
#     'unit': 'other'},
#    {'publicID': 'smi:nakamura81/amplitude/S14/00986',
#     'pickID': 'NA',
#     'genericAmplitude': '15.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00987'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-25T19:09:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00987',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00987',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00988'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-26T00:27:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00988',
#     'channelCode': '',
#     'locationCode': ''},
#    {'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-26T00:27:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00988',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00988',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'},
#    {'publicID': 'smi:nakamura81/amplitude/S14/00988',
#     'pickID': 'NA',
#     'genericAmplitude': '8.2',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00989'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-26T01:43:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00989',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00989',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00990'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-26T15:22:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00990',
#     'channelCode': '',
#     'locationCode': ''},
#    {'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-26T15:22:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00990',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00990',
#     'pickID': 'NA',
#     'genericAmplitude': '3.7',
#     'period': 'NA',
#     'unit': 'other'},
#    {'publicID': 'smi:nakamura81/amplitude/S14/00990',
#     'pickID': 'NA',
#     'genericAmplitude': '3.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00991'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-26T18:23:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00991',
#     'channelCode': '',
#     'locationCode': ''},
#    {'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-26T18:23:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00991',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00991',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'},
#    {'publicID': 'smi:nakamura81/amplitude/S14/00991',
#     'pickID': 'NA',
#     'genericAmplitude': '6.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00992'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-27T05:59:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00992',
#     'channelCode': '',
#     'locationCode': ''},
#    {'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-27T05:59:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00992',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00992',
#     'pickID': 'NA',
#     'genericAmplitude': '1.2',
#     'period': 'NA',
#     'unit': 'other'},
#    {'publicID': 'smi:nakamura81/amplitude/S14/00992',
#     'pickID': 'NA',
#     'genericAmplitude': '2.2',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00993'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-27T19:31:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00993',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00993',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00994'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-27T20:57:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00994',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00994',
#     'pickID': 'NA',
#     'genericAmplitude': '2.0',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00995'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-27T21:49:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00995',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00995',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00996'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-27T22:54:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00996',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00996',
#     'pickID': 'NA',
#     'genericAmplitude': '1.5',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00997'},
#   'eventType': ['meteorite'],
#   'eventDescription': ['meteoroid'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-27T23:36:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00997',
#     'channelCode': '',
#     'locationCode': ''},
#    {'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-27T23:36:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00997',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00997',
#     'pickID': 'NA',
#     'genericAmplitude': '8.5',
#     'period': 'NA',
#     'unit': 'other'},
#    {'publicID': 'smi:nakamura81/amplitude/S14/00997',
#     'pickID': 'NA',
#     'genericAmplitude': '3.2',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00998'},
#   'eventType': ['not reported'],
#   'eventDescription': ['unclassified'],
#   'picks': [{'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-29T06:28:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00998',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S14/00998',
#     'pickID': 'NA',
#     'genericAmplitude': '1.7',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/00999'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-29T16:39:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/00999',
#     'channelCode': '',
#     'locationCode': ''},
#    {'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-29T16:39:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/00999',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/00999',
#     'pickID': 'NA',
#     'genericAmplitude': '0.7',
#     'period': 'NA',
#     'unit': 'other'},
#    {'publicID': 'smi:nakamura81/amplitude/S14/00999',
#     'pickID': 'NA',
#     'genericAmplitude': '3.2',
#     'period': 'NA',
#     'unit': 'other'}]},
#  {'eventInfo': {'publicID': 'smi:nakamura81/event/01000'},
#   'eventType': ['earthquake'],
#   'eventDescription': ['deep moonquake'],
#   'picks': [{'stationCode': 'S12',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-30T02:49:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S12/01000',
#     'channelCode': '',
#     'locationCode': ''},
#    {'stationCode': 'S14',
#     'networkCode': 'XA',
#     'phase': 'P',
#     'time': '1971-03-30T02:49:00.000000Z',
#     'publicID': 'smi:nakamura81/pick/S14/01000',
#     'channelCode': '',
#     'locationCode': ''}],
#   'amplitudes': [{'publicID': 'smi:nakamura81/amplitude/S12/01000',
#     'pickID': 'NA',
#     'genericAmplitude': '1.0',
#     'period': 'NA',
#     'unit': 'other'},
#    {'publicID': 'smi:nakamura81/amplitude/S14/01000',
#     'pickID': 'NA',
#     'genericAmplitude': '2.7',
#     'period': 'NA',
#     'unit': 'other'}]},
#  ...]

# %%
import pandas as pd
df = pd.DataFrame(events)
df
# Out:
#                                         eventInfo       eventType  \
# 0      {'publicID': 'smi:nakamura81/event/00001'}    [earthquake]
# 1      {'publicID': 'smi:nakamura81/event/00002'}     [meteorite]
# 2      {'publicID': 'smi:nakamura81/event/00003'}    [earthquake]
# 3      {'publicID': 'smi:nakamura81/event/00004'}     [meteorite]
# 4      {'publicID': 'smi:nakamura81/event/00005'}     [meteorite]
# ...                                           ...             ...
# 13053  {'publicID': 'smi:nakamura81/event/13054'}     [meteorite]
# 13054  {'publicID': 'smi:nakamura81/event/13055'}     [meteorite]
# 13055  {'publicID': 'smi:nakamura81/event/13056'}     [meteorite]
# 13056  {'publicID': 'smi:nakamura81/event/13057'}  [not reported]
# 13057  {'publicID': 'smi:nakamura81/event/13058'}    [earthquake]
#
#                     eventDescription  \
# 0      [unclassified deep moonquake]
# 1                        [meteoroid]
# 2                   [deep moonquake]
# 3                        [meteoroid]
# 4                        [meteoroid]
# ...                              ...
# 13053                    [meteoroid]
# 13054                    [meteoroid]
# 13055                    [meteoroid]
# 13056                 [unclassified]
# 13057               [deep moonquake]
#
#                                                    picks  \
# 0      [{'stationCode': 'S11', 'networkCode': 'XA', '...
# 1      [{'stationCode': 'S11', 'networkCode': 'XA', '...
# 2      [{'stationCode': 'S11', 'networkCode': 'XA', '...
# 3      [{'stationCode': 'S11', 'networkCode': 'XA', '...
# 4      [{'stationCode': 'S11', 'networkCode': 'XA', '...
# ...                                                  ...
# 13053  [{'stationCode': 'S12', 'networkCode': 'XA', '...
# 13054  [{'stationCode': 'S12', 'networkCode': 'XA', '...
# 13055  [{'stationCode': 'S12', 'networkCode': 'XA', '...
# 13056  [{'stationCode': 'S14', 'networkCode': 'XA', '...
# 13057  [{'stationCode': 'S14', 'networkCode': 'XA', '...
#
#                                               amplitudes
# 0      [{'publicID': 'smi:nakamura81/amplitude/S11/00...
# 1      [{'publicID': 'smi:nakamura81/amplitude/S11/00...
# 2      [{'publicID': 'smi:nakamura81/amplitude/S11/00...
# 3      [{'publicID': 'smi:nakamura81/amplitude/S11/00...
# 4      [{'publicID': 'smi:nakamura81/amplitude/S11/00...
# ...                                                  ...
# 13053  [{'publicID': 'smi:nakamura81/amplitude/S12/13...
# 13054  [{'publicID': 'smi:nakamura81/amplitude/S12/13...
# 13055  [{'publicID': 'smi:nakamura81/amplitude/S12/13...
# 13056  [{'publicID': 'smi:nakamura81/amplitude/S14/13...
# 13057  [{'publicID': 'smi:nakamura81/amplitude/S14/13...
#
# [13058 rows x 5 columns]

# %%
for i in range(len(df['eventType'])):
    df['eventType'][i] = ' '.join(df['eventType'][i])
    df['eventDescription'][i] = ' '.join(df['eventDescription'][i])

# %%
# Save to CSV but does not retain lists in the columns
df.to_csv('events.csv')

# %%
# Pickle retains the lists properly
df.to_pickle('events.pkl')

# %%
df['picks'].to_excel("output.xlsx")

# %%
# See which events have 0, 1, 2, 3 or 4 stations associated with them
none=0
one=0
two=0
three=0
four=0
for x in df['picks']:
    if len(x) == 0:
        none+=1
    
    if len(x) == 1:
        one+=1
        
    if len(x) == 2:
        two+=1
        
    if len(x) == 3:
        three+=1
        
    if len(x) == 4:
        four+=1

print(f'None:{none}, Unique:{one}, Two times:{two}, Three times:{three}, Four times:{four}')
print('Check that sum is 13085: ')
print(none+one+two+three+four)
# Out:
# None:14, Unique:5717, Two times:3746, Three times:2157, Four times:1424
# Check that sum is 13085:
# 13058

# %%
# See which events have 0,1,2,3 or 4 amplitudes associated with them
anone=0
aone=0
atwo=0
athree=0
afour=0
for x in df['amplitudes']:
    
    if len(x) == 0:
        anone+=1
    
    if len(x) == 1:
        aone+=1
        
    if len(x) == 2:
        atwo+=1
        
    if len(x) == 3:
        athree+=1
        
    if len(x) == 4:
        afour+=1
print(f'None:{anone}, Unique:{aone}, Two times:{atwo}, Three times:{athree}, Four times:{afour}')
print('Check that sum is 13085: ')
print(anone+aone+atwo+athree+afour)
# Out:
# None:14, Unique:5806, Two times:3760, Three times:2232, Four times:1246
# Check that sum is 13085:
# 13058

# %%
df.to_excel('events.xlsx')
